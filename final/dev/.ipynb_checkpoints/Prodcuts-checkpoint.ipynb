# %% [markdown]
# ## Recommending Products

# %% [markdown]
# ### Loading

# %%
import pandas as pd

# %%
users_df = pd.read_csv('users.csv')

# %%
shops_df = pd.read_csv('shops.csv')

# %%
prods_df = pd.read_csv('products.csv')
prods_df = prods_df.rename(columns={'shop_prouct_id': 'shop_product_id'})

# %%
orders_df = pd.read_csv('orders.csv')

# %%
cats_df = pd.read_csv('categories.csv')

# %% [markdown]
# ### Query

# %%
user_id = 462154

# %%
shops_df.head()
# Out:
#    shop_id                        name  has_available_products  \
# 0        1         جت‌ مارت | میرداماد                       1
# 1        6          یاران دریان دادمان                       1
# 2        8  یاران دریان لوکس | نیاوران                       1
# 3       10       جت‌ مارت | تهران‌پارس                       1
# 4       11            جت مارت | کاشانی                       1
#
#    available_products_count  is_open      rate  rate_count  \
# 0                      1283        1  4.492411        8960
# 1                      1597        1  3.270781         794
# 2                      3181        1  4.174265         987
# 3                      1042        1  4.473160       10041
# 4                      1194        1  4.475088       12263
#
#                                            rate_tags  preparation_time  \
# 0  {"1":6781,"4":5247,"2":4702,"3":4546,"11":2735...                35
# 1  {"1":327,"4":282,"6":281,"3":206,"2":170,"11":...                35
# 2  {"1":733,"4":463,"3":324,"11":232,"2":231,"14"...                35
# 3  {"1":7663,"4":6192,"3":5441,"2":5125,"11":3302...                35
# 4  {"1":9133,"4":7814,"3":6063,"2":5620,"11":3841...                35
#
#    cart_close_limit  service_radius  service_radius_critical  latitude  \
# 0            400000               3                        1  35.76115
# 1            350000               3                        2  35.76455
# 2            350000               3                        1  35.81390
# 3            350000               4                        2  35.74524
# 4            350000               3                        1  35.73002
#
#    longitude
# 0   51.42338
# 1   51.35117
# 2   51.46145
# 3   51.52673
# 4   51.31180

# %%
prods_df.head()
# Out:
#    shop_product_id  shop_id  category_id  brand_id  \
# 0                3        1         26.0      30.0
# 1            20734        1         26.0      30.0
# 2             3438        1         25.0      33.0
# 3            20978        1         25.0      26.0
# 4            21472        1         22.0      29.0
#
#                                             title_fa  \
# 0                شامپو ضد ریزش شون حجم 400 میلی لیتر
# 1  ماسک موی شون با عصاره جینسینگ و کراتین حجم 150...
# 2         کرم مرطوب کننده هیدرودرم حجم 150 میلی لیتر
# 3   اسپری زنانه مای مدل Cool Ocean حجم 200 میلی لیتر
# 4                             کرم محافظ پای بچه آردن
#
#                                             title_en moderation_status  \
# 0                      Schon Anti Fall Shampoo 400ml          approved
# 1  Schon Ginseng and Keratin Extract Hair Mask 150ml          approved
# 2            Hydroderm Moisturizing Bowl Cream 150ml          approved
# 3                My Cool Ocean Spray For Women 200ml          approved
# 4                  Ardene Healing And Soothing Cream          approved
#
#                                                media description  \
# 0  [[468297,1,600,600,"jpg",[3],[]],[468335,1,600...         NaN
# 1  [[111787915,1,2500,2500,"jpg",[3],[]],[562967,...         NaN
# 2  [[239517,1,600,600,"jpg",[3],[]],[239575,1,600...         NaN
# 3  [[542814,1,600,600,"jpg",[3],[]],[542855,1,600...         NaN
# 4  [[290298,1,600,600,"jpg",[3],[]],[290366,1,600...         NaN
#
#    max_count_per_cart   price  discount  unit_price      vat  init_stock  \
# 0                 0.0  392000         0    359633.0  32367.0           4
# 1                 0.0  392000         0    359633.0  32367.0          23
# 2                 0.0  480742         0    441047.0  39695.0           5
# 3                 0.0  862000         0    790825.0  71175.0           9
# 4                 0.0  499688         0    458429.0  41259.0           5
#
#    remaining_stock
# 0                2
# 1               16
# 2                5
# 3                7
# 4                4

# %% [markdown]
# ### Filters

# %%
import geopy.distance

# %%
# filter nearby shops

# %%
user_lat = users_df.loc[users_df['id'] == user_id]['latitude'].tolist()[0]
user_long = users_df.loc[users_df['id'] == user_id]['longitude'].tolist()[0]

# %%
shops_lat = shops_df.latitude
shops_long = shops_df.longitude

# %%
dists = []
for s_lat, s_long in zip(shops_lat, shops_long):
    dist = geopy.distance.distance((s_lat, s_long), (user_lat, user_long)).km
    dists.append(dist)

# %%
shops_df['distance'] = dists

# %%
selected_shops_df = shops_df.loc[shops_df['distance'] < shops_df['service_radius']]
selected_shops_df = selected_shops_df.loc[selected_shops_df['has_available_products'] == 1]
selected_shops_df = selected_shops_df.loc[selected_shops_df['is_open'] == 1]

# %%
# get products in those shops

# %%
product_shop_df = pd.merge(prods_df, selected_shops_df[['shop_id', 'rate', 'service_radius', 'distance']], on=['shop_id'])

# %%
product_shop_df = product_shop_df.loc[product_shop_df['moderation_status'] == 'approved']

# %%
product_shop_df = product_shop_df.loc[product_shop_df['remaining_stock'] > 0]

# %%
product_shop_df.head()
# Out:
#    shop_product_id  shop_id  category_id  brand_id  \
# 0          1465551       84         26.0    1027.0
# 1           208410       84         26.0    1027.0
# 2           208411       84         37.0    1191.0
# 3          1198988       84         37.0    1191.0
# 4           208281       84         38.0    1308.0
#
#                              title_fa                            title_en  \
# 0     ژل موی سر آتوسا (750 میلی لیتر)     ژل موی سر آتوسا (750 میلی لیتر)
# 1           ژل موی سر آتوسا (100 میل)           ژل موی سر آتوسا (100 میل)
# 2    کیک شوکووان وانیلی آشنا (43 گرم)    کیک شوکووان وانیلی آشنا (43 گرم)
# 3  کیک شوکووان کاکائویی آشنا (43 گرم)  کیک شوکووان کاکائویی آشنا (43 گرم)
# 4    آبغوره بدون نمک كامبيز (475 گرم)    آبغوره بدون نمک كامبيز (475 گرم)
#
#   moderation_status                                              media  \
# 0          approved  [["788bc5f5872352630aefc59533d2748fdc4fd45b_16...
# 1          approved  [["1e1d2722c59905d087752aeca5f942a3fff22c51_16...
# 2          approved  [["c365884719067726e11581b3032bd5b2d17051e0_16...
# 3          approved  [["ca9c872366e2fd16cce0f1aba95eea7a0826b790_16...
# 4          approved  [["1d3e1c55d7bfe9080b7007b03952393cf81645ab_16...
#
#   description  max_count_per_cart   price  discount  unit_price      vat  \
# 0     750 میل                 0.0  470000         0    431192.0  38808.0
# 1     100 میل                 0.0  150000         0    137614.0  12386.0
# 2      43 گرم                 0.0   40000         0     36697.0   3303.0
# 3      43 گرم                 0.0   45000         0     41284.0   3716.0
# 4     475 گرم                 0.0  245000         0    224770.0  20230.0
#
#    init_stock  remaining_stock      rate  service_radius  distance
# 0           3                3  4.066288               3  1.313627
# 1          22               21  4.066288               3  1.313627
# 2          22               22  4.066288               3  1.313627
# 3          12                9  4.066288               3  1.313627
# 4          12               12  4.066288               3  1.313627

# %% [markdown]
# ### Blind Score

# %%
# most bought products come first

# %%
orders_prods_df = pd.merge(product_shop_df[['shop_product_id']], orders_df, on=['shop_product_id'])

# %%
len(orders_prods_df)
# Out:
# 149

# %%
top_bought_products = orders_prods_df.groupby(['shop_id', 'shop_product_id']).size().to_frame('n_buy_all').reset_index()

# %%
top_bought_products = top_bought_products.sort_values(by='n_buy_all', ascending=False)

# %%
top_bought_products.head()
# Out:
#     shop_id  shop_product_id  n_buy_all
# 49      424          1182666         11
# 52      424          1182685          5
# 50      424          1182681          5
# 48      424          1182664          4
# 47      424          1182659          4

# %%
prod_ids = [tuple(x) for x in top_bought_products[['shop_id', 'shop_product_id']].values]

# %%
prod_ids[:20]
# Out:
# [(424, 1182666),
#  (424, 1182685),
#  (424, 1182681),
#  (424, 1182664),
#  (424, 1182659),
#  (1274, 1604095),
#  (624, 1368048),
#  (624, 1369315),
#  (624, 1369720),
#  (624, 1369648),
#  (624, 1369591),
#  (624, 1369589),
#  (624, 1369461),
#  (624, 1369307),
#  (624, 1368083),
#  (624, 1368077),
#  (624, 1369062),
#  (624, 1370262),
#  (624, 1368968),
#  (624, 1369433)]

# %% [markdown]
# ### User Specific Score

# %%
# top categories that user buys from

# %%
user_orders_df = orders_df.loc[orders_df.user_id == user_id]

# %%
user_orders_cat_df = pd.merge(user_orders_df, prods_df[['shop_product_id', 'category_id']], on=['shop_product_id'])

# %%
user_orders_cat_df
# Out:
#    user_id  user_address_id  shop_id  shop_product_id  order_id  \
# 0   462154          1492647       42            66533    906245
#
#    order_item_id  order_shipment_id    order_status  order_payable_price  \
# 0        2645485             857487  full_delivered               302000
#
#    order_discount  order_shipping_cost_total order_checkout_status  \
# 0          200000                          0         complete_paid
#
#    order_item_quantity  order_item_payable_price  order_item_discount  \
# 0                    1                     18048                11952
#
#   order_shipment_status order_shipment_delivery_status  rate    tags  \
# 0             delivered                      delivered     5  [1, 4]
#
#    category_id
# 0         66.0

# %%
category_score = user_orders_cat_df.groupby(['category_id']).size().to_frame('cat_score').reset_index()

# %%
category_score
# Out:
#    category_id  cat_score
# 0         66.0          1

# %%
user_orders_cat_df = pd.merge(user_orders_cat_df, category_score, on=['category_id'])

# %%
user_orders_cat_df
# Out:
#    user_id  user_address_id  shop_id  shop_product_id  order_id  \
# 0   462154          1492647       42            66533    906245
#
#    order_item_id  order_shipment_id    order_status  order_payable_price  \
# 0        2645485             857487  full_delivered               302000
#
#    order_discount  ...  order_checkout_status order_item_quantity  \
# 0          200000  ...          complete_paid                   1
#
#    order_item_payable_price  order_item_discount  order_shipment_status  \
# 0                     18048                11952              delivered
#
#   order_shipment_delivery_status rate    tags category_id  cat_score
# 0                      delivered    5  [1, 4]        66.0          1
#
# [1 rows x 21 columns]

# %%
top_bought_products = pd.merge(top_bought_products, prods_df[['shop_id', 'shop_product_id', 'category_id']], on=['shop_id','shop_product_id'])

# %%
top_bought_products
# Out:
#      shop_id  shop_product_id  n_buy_all  category_id
# 0        424          1182666         11         89.0
# 1        424          1182685          5        106.0
# 2        424          1182681          5        106.0
# 3        424          1182664          4        106.0
# 4        424          1182659          4        106.0
# ..       ...              ...        ...          ...
# 112       84           852143          1         89.0
# 113       84           842884          1         37.0
# 114       84           821018          1         34.0
# 115       84           811984          1         34.0
# 116     1687          1684235          1        146.0
#
# [117 rows x 4 columns]

# %%
top_bought_products_top_cat = pd.merge(top_bought_products, category_score, on=['category_id'])

# %%
top_bought_products_top_cat = top_bought_products_top_cat.sort_values(by='n_buy_all', ascending=False)

# %%
top_bought_products_top_cat
# Out:
#    shop_id  shop_product_id  n_buy_all  category_id  cat_score
# 0      624          1368048          2         66.0          1
# 1      624          1368077          2         66.0          1
# 2      624          1370262          1         66.0          1
# 3      624          1368084          1         66.0          1
# 4      624          1368074          1         66.0          1

# %%
prod_ids = [tuple(x) for x in top_bought_products_top_cat[['shop_id', 'shop_product_id']].values]

# %%
if len(prod_ids) < 20:
    extra_prod_ids = [tuple(x) for x in top_bought_products[['shop_id', 'shop_product_id']].values]
    prod_ids = prod_ids + extra_prod_ids[:20-len(prod_ids)]

# %%
prod_ids
# Out:
# [(624, 1368048),
#  (624, 1368077),
#  (624, 1370262),
#  (624, 1368084),
#  (624, 1368074),
#  (424, 1182666),
#  (424, 1182685),
#  (424, 1182681),
#  (424, 1182664),
#  (424, 1182659),
#  (1274, 1604095),
#  (624, 1368048),
#  (624, 1369315),
#  (624, 1369315),
#  (624, 1369720),
#  (624, 1369648),
#  (624, 1369648),
#  (624, 1369591),
#  (624, 1369591),
#  (624, 1369589)]
