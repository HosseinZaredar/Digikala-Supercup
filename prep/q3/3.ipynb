# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd

# %%
X_df = pd.read_csv('purchase_history.csv')

# %%
X_df.rename(columns={'created_at': 'date', 'user_id': 'customer', 'product_id': 'product'}, 
          inplace=True)

# %%
X_df.head()
# Out:
#    customer  product        date
# 0    647746  2011564  2019-02-09
# 1    906136  4105782  2019-11-23
# 2  12862997  2144063  2019-07-16
# 3  12097079  1207738  2019-04-05
# 4   3184486  4278839  2019-03-08

# %% [markdown]
# ### Split Dataset (8 - 4 Months)

# %%
X_df['date'] = pd.to_datetime(X_df['date'])

# %%
date_min = X_df['date'].min()
date_max = X_df['date'].max()

# %%
print(date_min, date_max)
# Out:
# 2019-01-02 00:00:00 2019-12-31 00:00:00

# %%
X_df_8 = X_df[X_df.date < pd.Timestamp(2019, 9,1)].reset_index(drop=True)

# %%
X_df_4 = X_df[X_df.date >= pd.Timestamp(2019, 9, 1)].reset_index(drop=True)

# %% [markdown]
# ### Finding Last & Next Purchases and Differences

# %%
last_purchase = X_df_8.groupby(['customer', 'product']).date.max().reset_index()
last_purchase.columns = ['customer', 'product', 'last_purchase']

# %%
next_purchase = X_df_4.groupby(['customer', 'product']).date.min().reset_index()
next_purchase.columns = ['customer', 'product', 'next_purchase']

# %%
purchase_dates = pd.merge(last_purchase, next_purchase, on=['customer', 'product'], how='left')

# %%
purchase_dates['next_purchase_day'] = (purchase_dates['next_purchase'] - purchase_dates['last_purchase']).dt.days

# %%
purchase_dates.head()
# Out:
#    customer  product last_purchase next_purchase  next_purchase_day
# 0    577243   724112    2019-06-29           NaT                NaN
# 1    577243   875550    2019-06-16           NaT                NaN
# 2    577243   895941    2019-08-23    2019-12-13              112.0
# 3    577243   895955    2019-05-12    2019-10-17              158.0
# 4    577243   896036    2019-05-16    2019-09-15              122.0

# %%
purchase_dates.next_purchase_day.describe()
# Out:
# count    169409.000000
# mean         67.047925
# std          52.371211
# min           1.000000
# 25%          28.000000
# 50%          53.000000
# 75%          92.000000
# max         349.000000
# Name: next_purchase_day, dtype: float64

# %%
ctm_dt = purchase_dates[['customer', 'product', 'next_purchase_day']]

# %%
ctm_dt.head()
# Out:
#    customer  product  next_purchase_day
# 0    577243   724112                NaN
# 1    577243   875550                NaN
# 2    577243   895941              112.0
# 3    577243   895955              158.0
# 4    577243   896036              122.0

# %% [markdown]
# ### Extracting Features: Frequency

# %%
frequency = X_df_8.groupby(['customer', 'product']).date.count().reset_index()
frequency.columns = ['customer', 'product', 'frequency']

ctm_dt = pd.merge(ctm_dt, frequency, on=['customer', 'product'])

# %%
ctm_dt.head()
# Out:
#    customer  product  next_purchase_day  frequency
# 0    577243   724112                NaN          5
# 1    577243   875550                NaN          4
# 2    577243   895941              112.0         10
# 3    577243   895955              158.0          2
# 4    577243   896036              122.0         10

# %% [markdown]
# ### Extracting Features: Days Between The Last 3 Purchases

# %%
day_order = X_df_8[['customer', 'product', 'date']]
day_order['date'] = day_order['date'].dt.date

# %%
day_order = day_order.sort_values(['customer', 'product', 'date'])
day_order = day_order.drop_duplicates(subset=['customer', 'product', 'date'], keep='first')

# %%
day_order.head()
# Out:
#          customer  product        date
# 49727      577243   724112  2019-03-13
# 948315     577243   724112  2019-03-25
# 304174     577243   724112  2019-04-22
# 1351903    577243   724112  2019-06-16
# 718283     577243   724112  2019-06-29

# %%
day_order['prev_date'] = day_order.groupby(['customer', 'product'])['date'].shift(1)
day_order['t2_date'] = day_order.groupby(['customer', 'product'])['date'].shift(2)
day_order['t3_date'] = day_order.groupby(['customer', 'product'])['date'].shift(3)

# %%
day_order.head()
# Out:
#          customer  product        date   prev_date     t2_date     t3_date
# 49727      577243   724112  2019-03-13         NaN         NaN         NaN
# 948315     577243   724112  2019-03-25  2019-03-13         NaN         NaN
# 304174     577243   724112  2019-04-22  2019-03-25  2019-03-13         NaN
# 1351903    577243   724112  2019-06-16  2019-04-22  2019-03-25  2019-03-13
# 718283     577243   724112  2019-06-29  2019-06-16  2019-04-22  2019-03-25

# %%
day_order['day_diff'] = (day_order['date'] - day_order['prev_date']).dt.days
day_order['day_diff_2'] = (day_order['prev_date'] - day_order['t2_date']).dt.days
day_order['day_diff_3'] = (day_order['t2_date'] - day_order['t3_date']).dt.days

# %%
day_order.head()
# Out:
#          customer  product        date   prev_date     t2_date     t3_date  \
# 49727      577243   724112  2019-03-13         NaN         NaN         NaN
# 948315     577243   724112  2019-03-25  2019-03-13         NaN         NaN
# 304174     577243   724112  2019-04-22  2019-03-25  2019-03-13         NaN
# 1351903    577243   724112  2019-06-16  2019-04-22  2019-03-25  2019-03-13
# 718283     577243   724112  2019-06-29  2019-06-16  2019-04-22  2019-03-25
#
#          day_diff  day_diff_2  day_diff_3
# 49727         NaN         NaN         NaN
# 948315       12.0         NaN         NaN
# 304174       28.0        12.0         NaN
# 1351903      55.0        28.0        12.0
# 718283       13.0        55.0        28.0

# %% [markdown]
# ### Extracting Features: Mean & STD of The Difference Between Purchases

# %%
day_diff = day_order.groupby(['customer', 'product']).agg({'day_diff': ['mean','std']}).reset_index()
day_diff.columns = ['customer', 'product', 'day_diff_mean','day_diff_std']

# %%
day_diff.head()
# Out:
#    customer  product  day_diff_mean  day_diff_std
# 0    577243   724112      27.000000     20.049938
# 1    577243   875550      49.333333     21.221059
# 2    577243   895941      24.000000     27.060118
# 3    577243   895955      99.000000           NaN
# 4    577243   896036      14.777778      9.909311

# %% [markdown]
# ### Removing Customer-Product Pairs with Less Than Count 3

# %%
day_order_last = day_order.drop_duplicates(subset=['customer', 'product'], keep='last')

# %%
day_order_last = day_order_last.dropna()

# %%
day_order_last.head()
# Out:
#          customer  product        date   prev_date     t2_date     t3_date  \
# 718283     577243   724112  2019-06-29  2019-06-16  2019-04-22  2019-03-25
# 1106330    577243   875550  2019-06-16  2019-04-13  2019-02-13  2019-01-19
# 964647     577243   895941  2019-08-23  2019-06-29  2019-06-21  2019-06-16
# 1299273    577243   896036  2019-05-16  2019-05-12  2019-04-13  2019-03-13
# 1378901    577243   896067  2019-08-23  2019-05-12  2019-04-22  2019-02-22
#
#          day_diff  day_diff_2  day_diff_3
# 718283       13.0        55.0        28.0
# 1106330      64.0        59.0        25.0
# 964647       55.0         8.0         5.0
# 1299273       4.0        29.0        31.0
# 1378901     103.0        20.0        59.0

# %% [markdown]
# ### Merging All The Features

# %%
day_order_last = pd.merge(day_order_last, day_diff, on=['customer', 'product'])

# %%
day_order_last
# Out:
#         customer  product        date   prev_date     t2_date     t3_date  \
# 0         577243   724112  2019-06-29  2019-06-16  2019-04-22  2019-03-25
# 1         577243   875550  2019-06-16  2019-04-13  2019-02-13  2019-01-19
# 2         577243   895941  2019-08-23  2019-06-29  2019-06-21  2019-06-16
# 3         577243   896036  2019-05-16  2019-05-12  2019-04-13  2019-03-13
# 4         577243   896067  2019-08-23  2019-05-12  2019-04-22  2019-02-22
# ...          ...      ...         ...         ...         ...         ...
# 212352  45338907   778755  2019-08-03  2019-07-14  2019-05-25  2019-04-23
# 212353  45339741   903335  2019-07-20  2019-06-10  2019-04-27  2019-02-21
# 212354  45339741   975982  2019-08-30  2019-08-03  2019-07-16  2019-06-10
# 212355  45431507  4375282  2019-08-27  2019-07-11  2019-06-20  2019-04-08
# 212356  45471482  1945563  2019-08-10  2019-03-17  2019-02-27  2019-02-17
#
#         day_diff  day_diff_2  day_diff_3  day_diff_mean  day_diff_std
# 0           13.0        55.0        28.0      27.000000     20.049938
# 1           64.0        59.0        25.0      49.333333     21.221059
# 2           55.0         8.0         5.0      24.000000     27.060118
# 3            4.0        29.0        31.0      14.777778      9.909311
# 4          103.0        20.0        59.0      60.666667     41.525093
# ...          ...         ...         ...            ...           ...
# 212352      20.0        50.0        32.0      34.000000     15.099669
# 212353      40.0        44.0        65.0      41.750000     19.259197
# 212354      27.0        18.0        36.0      22.875000     12.123619
# 212355      47.0        21.0        73.0      47.000000     26.000000
# 212356     146.0        18.0        10.0      58.000000     76.315136
#
# [212357 rows x 11 columns]

# %%
features = pd.merge(ctm_dt, day_order_last, on=['customer', 'product'])

# %%
features = features.dropna()

# %%
features
# Out:
#         customer  product  next_purchase_day  frequency        date  \
# 2         577243   895941              112.0         10  2019-08-23
# 3         577243   896036              122.0         10  2019-05-16
# 5         577243   967949               67.0          4  2019-08-23
# 6         577243   968036              236.0          5  2019-02-10
# 11        577243   968429               49.0          9  2019-08-22
# ...          ...      ...                ...        ...         ...
# 212349  45335223   816699               61.0          8  2019-07-08
# 212350  45335223  3165743               26.0         13  2019-08-29
# 212351  45335223  4960959               48.0         12  2019-08-06
# 212352  45338907   778755              105.0         11  2019-08-03
# 212354  45339741   975982               70.0          9  2019-08-30
#
#          prev_date     t2_date     t3_date  day_diff  day_diff_2  day_diff_3  \
# 2       2019-06-29  2019-06-21  2019-06-16      55.0         8.0         5.0
# 3       2019-05-12  2019-04-13  2019-03-13       4.0        29.0        31.0
# 5       2019-02-13  2019-02-02  2019-01-26     191.0        11.0         7.0
# 6       2019-02-02  2019-01-31  2019-01-26       8.0         2.0         5.0
# 11      2019-06-21  2019-05-24  2019-05-16      62.0        28.0         8.0
# ...            ...         ...         ...       ...         ...         ...
# 212349  2019-06-21  2019-06-02  2019-04-20      17.0        19.0        43.0
# 212350  2019-07-28  2019-06-18  2019-06-08      32.0        40.0        10.0
# 212351  2019-07-31  2019-07-08  2019-07-07       6.0        23.0         1.0
# 212352  2019-07-14  2019-05-25  2019-04-23      20.0        50.0        32.0
# 212354  2019-08-03  2019-07-16  2019-06-10      27.0        18.0        36.0
#
#         day_diff_mean  day_diff_std
# 2           24.000000     27.060118
# 3           14.777778      9.909311
# 5           69.666667    105.096781
# 6            5.000000      3.000000
# 11          24.125000     17.787937
# ...               ...           ...
# 212349      26.333333     14.468356
# 212350      23.000000     15.362291
# 212351      12.000000     10.230673
# 212352      34.000000     15.099669
# 212354      22.875000     12.123619
#
# [80671 rows x 13 columns]

# %% [markdown]
# ### Preparing The Labels

# %%
labels = features.next_purchase_day

# %%
features = features.drop('next_purchase_day', 1)

# %%
labels.describe()
# Out:
# count    80671.000000
# mean        57.712524
# std         45.161480
# min          1.000000
# 25%         25.000000
# 50%         46.000000
# 75%         79.000000
# max        349.000000
# Name: next_purchase_day, dtype: float64

# %%
features.describe()
# Out:
#            customer       product     frequency      day_diff    day_diff_2  \
# count  8.067100e+04  8.067100e+04  80671.000000  80671.000000  80671.000000
# mean   9.278442e+06  1.987991e+06      7.117787     31.291381     30.327937
# std    8.213218e+06  1.295263e+06      5.402620     28.867234     28.282869
# min    5.772430e+05  1.140440e+05      4.000000      1.000000      1.000000
# 25%    3.364980e+06  9.158320e+05      4.000000     11.000000     10.000000
# 50%    6.915487e+06  1.625941e+06      5.000000     23.000000     22.000000
# 75%    1.261206e+07  2.940875e+06      8.000000     42.000000     41.000000
# max    4.533974e+07  6.058017e+06    328.000000    227.000000    229.000000
#
#          day_diff_3  day_diff_mean  day_diff_std
# count  80671.000000   80671.000000  80671.000000
# mean      30.960296      31.090998     23.017821
# std       29.678013      16.259094     16.864820
# min        1.000000       1.000000      0.000000
# 25%       10.000000      18.333333     10.954451
# 50%       21.000000      28.666667     18.681542
# 75%       42.000000      41.666667     30.512293
# max      233.000000      80.333333    132.805622

# %% [markdown]
# ### Categorical to One-Hot

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
def train_onehot(dataframe):
    enc = OneHotEncoder(handle_unknown='ignore')
    enc.fit(dataframe)
    return enc

# %%
cat_columns = ['customer', 'product']

# %%
onehot_model = train_onehot(features[cat_columns])

# %%
train_cat = onehot_model.transform(features[cat_columns])

# %%
train_cat.shape
# Out:
# (80671, 47650)

# %% [markdown]
# ### Numerical to Categorical

# %%
from scipy.sparse import hstack
import numpy as np

# %%
def train_num2cat(dataframe, num_bins):
    bins = pd.qcut(dataframe, duplicates='drop', q=num_bins, retbins=True)[1]
    bins = np.concatenate(([-np.inf], bins[1:-1], [np.inf]))
    res_df = pd.cut(dataframe, bins).to_frame()
    oh_model = train_onehot(res_df)
    return bins, oh_model

# %%
def transform_num2cat(dataframe, model, bins):
    res_df = pd.cut(dataframe, bins).to_frame()
    return model.transform(res_df)

# %%
numer_colums = ['frequency', 'day_diff', 'day_diff_2', 'day_diff_3', 'day_diff_mean', 'day_diff_std']

# %%
numer_bins, numer_models = [], []

# %%
for col in numer_colums:
    numer_bin, numer_model = train_num2cat(features[col], 10)
    numer_bins.append(numer_bin)
    numer_models.append(numer_model)

# %%
numers = [transform_num2cat(features[numer_colums[i]], numer_model, numer_bin)
          for i, (numer_bin, numer_model) in enumerate(zip(numer_bins, numer_models))]

# %%
train_numer = hstack(numers)

# %%
train_numer.shape
# Out:
# (80671, 56)

# %% [markdown]
# ### Input-Output of The Model

# %%
train_X = hstack((train_numer, train_cat))

# %%
train_y = labels.to_list()

# %% [markdown]
# ### Train-Validation Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size=0.1, random_state=0)

# %% [markdown]
# ### Building & Training The Model

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=4)

# %%
reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=4)

# %% [markdown]
# ### Evaluation

# %%
reg.score(X_train, y_train)
# Out:
# 0.48681015919175163

# %%
reg.score(X_val, y_val)
# Out:
# 0.23490478809413795

# %% [markdown]
# ### Future Predictions

# %%
last_purchase = X_df.groupby(['customer', 'product']).date.max().reset_index()
last_purchase.columns = ['customer', 'product', 'last_purchase']

# %%
last_purchase
# Out:
#         customer  product last_purchase
# 0         577243   724112    2019-06-29
# 1         577243   875550    2019-06-16
# 2         577243   895941    2019-12-13
# 3         577243   895955    2019-10-29
# 4         577243   896036    2019-10-10
# ...          ...      ...           ...
# 318045  45431507  4375282    2019-08-27
# 318046  45443053  1660612    2019-12-24
# 318047  45471482  1945563    2019-08-10
# 318048  45471482  3309954    2019-11-15
# 318049  45471482  4563945    2019-11-15
#
# [318050 rows x 3 columns]

# %%
max_purchase = X_df.groupby(['customer', 'product']).date.max().reset_index()
max_purchase.columns = ['customer', 'product', 'last_purchase']

max_purchase['recency'] = (pd.Timestamp(2019, 12,31) - max_purchase['last_purchase']).dt.days

# %%
max_purchase
# Out:
#         customer  product last_purchase  recency
# 0         577243   724112    2019-06-29      185
# 1         577243   875550    2019-06-16      198
# 2         577243   895941    2019-12-13       18
# 3         577243   895955    2019-10-29       63
# 4         577243   896036    2019-10-10       82
# ...          ...      ...           ...      ...
# 318045  45431507  4375282    2019-08-27      126
# 318046  45443053  1660612    2019-12-24        7
# 318047  45471482  1945563    2019-08-10      143
# 318048  45471482  3309954    2019-11-15       46
# 318049  45471482  4563945    2019-11-15       46
#
# [318050 rows x 4 columns]

# %%
frequency = X_df.groupby(['customer', 'product']).date.count().reset_index()
frequency.columns = ['customer', 'product', 'frequency']

# %%
frequency
# Out:
#         customer  product  frequency
# 0         577243   724112          5
# 1         577243   875550          4
# 2         577243   895941         11
# 3         577243   895955          4
# 4         577243   896036         12
# ...          ...      ...        ...
# 318045  45431507  4375282          4
# 318046  45443053  1660612         45
# 318047  45471482  1945563          4
# 318048  45471482  3309954          4
# 318049  45471482  4563945          7
#
# [318050 rows x 3 columns]

# %%
day_order = X_df[['customer', 'product', 'date']]
day_order['date'] = day_order['date'].dt.date

day_order = day_order.sort_values(['customer', 'product', 'date'])
day_order = day_order.drop_duplicates(subset=['customer', 'product', 'date'], keep='first')

day_order.head()

day_order['prev_date'] = day_order.groupby(['customer', 'product'])['date'].shift(1)
day_order['t2_date'] = day_order.groupby(['customer', 'product'])['date'].shift(2)
day_order['t3_date'] = day_order.groupby(['customer', 'product'])['date'].shift(3)

day_order.head()

day_order['day_diff'] = (day_order['date'] - day_order['prev_date']).dt.days
day_order['day_diff_2'] = (day_order['prev_date'] - day_order['t2_date']).dt.days
day_order['day_diff_3'] = (day_order['t2_date'] - day_order['t3_date']).dt.days

# %%
day_order
# Out:
#          customer  product        date   prev_date     t2_date     t3_date  \
# 68489      577243   724112  2019-03-13         NaN         NaN         NaN
# 1304270    577243   724112  2019-03-25  2019-03-13         NaN         NaN
# 418727     577243   724112  2019-04-22  2019-03-25  2019-03-13         NaN
# 1859117    577243   724112  2019-06-16  2019-04-22  2019-03-25  2019-03-13
# 988009     577243   724112  2019-06-29  2019-06-16  2019-04-22  2019-03-25
# ...           ...      ...         ...         ...         ...         ...
# 1377731  45471482  4563945  2019-10-17  2019-10-04  2019-10-01         NaN
# 1695845  45471482  4563945  2019-10-29  2019-10-17  2019-10-04  2019-10-01
# 1121576  45471482  4563945  2019-11-10  2019-10-29  2019-10-17  2019-10-04
# 1535111  45471482  4563945  2019-11-11  2019-11-10  2019-10-29  2019-10-17
# 759240   45471482  4563945  2019-11-15  2019-11-11  2019-11-10  2019-10-29
#
#          day_diff  day_diff_2  day_diff_3
# 68489         NaN         NaN         NaN
# 1304270      12.0         NaN         NaN
# 418727       28.0        12.0         NaN
# 1859117      55.0        28.0        12.0
# 988009       13.0        55.0        28.0
# ...           ...         ...         ...
# 1377731      13.0         3.0         NaN
# 1695845      12.0        13.0         3.0
# 1121576      12.0        12.0        13.0
# 1535111       1.0        12.0        12.0
# 759240        4.0         1.0        12.0
#
# [1958981 rows x 9 columns]

# %%
day_diff = day_order.groupby(['customer', 'product']).agg({'day_diff': ['mean','std']}).reset_index()
day_diff.columns = ['customer', 'product', 'day_diff_mean', 'day_diff_std']

# %%
day_diff
# Out:
#         customer  product  day_diff_mean  day_diff_std
# 0         577243   724112      27.000000     20.049938
# 1         577243   875550      49.333333     21.221059
# 2         577243   895941      32.800000     37.752998
# 3         577243   895955      89.666667     73.446125
# 4         577243   896036      25.454545     33.365742
# ...          ...      ...            ...           ...
# 318045  45431507  4375282      47.000000     26.000000
# 318046  45443053  1660612       3.714286      4.344917
# 318047  45471482  1945563      58.000000     76.315136
# 318048  45471482  3309954       5.000000      2.645751
# 318049  45471482  4563945       7.500000      5.394442
#
# [318050 rows x 4 columns]

# %%
day_order.rename(columns={'date': 'last_purchase'}, inplace=True)
last_purchase['last_purchase'] = last_purchase['last_purchase'].dt.date
day_order = pd.merge(last_purchase, day_order, on=['customer', 'product', 'last_purchase'], how='left')

# %%
day_order
# Out:
#         customer  product last_purchase   prev_date     t2_date     t3_date  \
# 0         577243   724112    2019-06-29  2019-06-16  2019-04-22  2019-03-25
# 1         577243   875550    2019-06-16  2019-04-13  2019-02-13  2019-01-19
# 2         577243   895941    2019-12-13  2019-08-23  2019-06-29  2019-06-21
# 3         577243   895955    2019-10-29  2019-10-17  2019-05-12  2019-02-02
# 4         577243   896036    2019-10-10  2019-09-15  2019-05-16  2019-05-12
# ...          ...      ...           ...         ...         ...         ...
# 318045  45431507  4375282    2019-08-27  2019-07-11  2019-06-20  2019-04-08
# 318046  45443053  1660612    2019-12-24  2019-12-07  2019-12-06  2019-12-04
# 318047  45471482  1945563    2019-08-10  2019-03-17  2019-02-27  2019-02-17
# 318048  45471482  3309954    2019-11-15  2019-11-11  2019-11-08  2019-10-31
# 318049  45471482  4563945    2019-11-15  2019-11-11  2019-11-10  2019-10-29
#
#         day_diff  day_diff_2  day_diff_3
# 0           13.0        55.0        28.0
# 1           64.0        59.0        25.0
# 2          112.0        55.0         8.0
# 3           12.0       158.0        99.0
# 4           25.0       122.0         4.0
# ...          ...         ...         ...
# 318045      47.0        21.0        73.0
# 318046      17.0         1.0         2.0
# 318047     146.0        18.0        10.0
# 318048       4.0         3.0         8.0
# 318049       4.0         1.0        12.0
#
# [318050 rows x 9 columns]

# %% [markdown]
# ### Merging Features

# %%
features = pd.merge(last_purchase, max_purchase[['customer', 'product', 'recency']], on=['customer', 'product'])

# %%
features = pd.merge(features, frequency, on=['customer', 'product'])

# %%
features = pd.merge(features, day_order[['customer', 'product', 'day_diff', 'day_diff_2', 'day_diff_3']], on=['customer', 'product'])

# %%
features = pd.merge(features, day_diff, on=['customer', 'product'])

# %%
features = features[['customer', 'product', 'recency', 'frequency', 'day_diff', 'day_diff_2', 'day_diff_3',
                     'day_diff_mean', 'day_diff_std']]

# %%
features
# Out:
#         customer  product  recency  frequency  day_diff  day_diff_2  \
# 0         577243   724112      185          5      13.0        55.0
# 1         577243   875550      198          4      64.0        59.0
# 2         577243   895941       18         11     112.0        55.0
# 3         577243   895955       63          4      12.0       158.0
# 4         577243   896036       82         12      25.0       122.0
# ...          ...      ...      ...        ...       ...         ...
# 318045  45431507  4375282      126          4      47.0        21.0
# 318046  45443053  1660612        7         45      17.0         1.0
# 318047  45471482  1945563      143          4     146.0        18.0
# 318048  45471482  3309954       46          4       4.0         3.0
# 318049  45471482  4563945       46          7       4.0         1.0
#
#         day_diff_3  day_diff_mean  day_diff_std
# 0             28.0      27.000000     20.049938
# 1             25.0      49.333333     21.221059
# 2              8.0      32.800000     37.752998
# 3             99.0      89.666667     73.446125
# 4              4.0      25.454545     33.365742
# ...            ...            ...           ...
# 318045        73.0      47.000000     26.000000
# 318046         2.0       3.714286      4.344917
# 318047        10.0      58.000000     76.315136
# 318048         8.0       5.000000      2.645751
# 318049        12.0       7.500000      5.394442
#
# [318050 rows x 9 columns]

# %%
features.describe()
# Out:
#            customer       product        recency      frequency  \
# count  3.180500e+05  3.180500e+05  318050.000000  318050.000000
# mean   1.000785e+07  2.141462e+06     117.411181       6.836809
# std    8.817177e+06  1.401675e+06      77.911267      18.030780
# min    5.772430e+05  1.136460e+05       0.000000       4.000000
# 25%    3.527045e+06  9.678040e+05      54.000000       4.000000
# 50%    7.368366e+06  1.797684e+06     101.000000       5.000000
# 75%    1.341542e+07  3.154877e+06     169.000000       7.000000
# max    4.547148e+07  7.381721e+06     359.000000    7618.000000
#
#             day_diff     day_diff_2     day_diff_3  day_diff_mean  \
# count  318050.000000  318050.000000  318050.000000  318050.000000
# mean       36.443754      34.520623      34.573067      35.119698
# std        37.032948      35.635061      36.489303      20.968358
# min         1.000000       1.000000       1.000000       1.000000
# 25%        11.000000      10.000000      10.000000      18.800000
# 50%        25.000000      23.000000      22.000000      31.333333
# 75%        49.000000      46.000000      46.000000      47.666667
# max       349.000000     334.000000     338.000000     119.333333
#
#         day_diff_std
# count  318050.000000
# mean       27.264249
# std        22.240279
# min         0.000000
# 25%        11.523888
# 50%        21.221059
# 75%        36.473735
# max       194.279009

# %% [markdown]
# ### Encoding

# %%
test_cat = onehot_model.transform(features[cat_columns])

# %%
numers = [transform_num2cat(features[numer_colums[i]], numer_model, numer_bin)
          for i, (numer_bin, numer_model) in enumerate(zip(numer_bins, numer_models))]

# %%
test_numer = hstack(numers)

# %%
test_X = hstack((test_numer, test_cat))

# %%
test_X.shape
# Out:
# (318050, 47706)

# %% [markdown]
# ### Predicting

# %%
preds = reg.predict(test_X)

# %%
preds = [int(p) for p in preds]

# %%
out_df = last_purchase[['customer', 'product', 'last_purchase']]

# %%
out_df
# Out:
#         customer  product last_purchase
# 0         577243   724112    2019-06-29
# 1         577243   875550    2019-06-16
# 2         577243   895941    2019-12-13
# 3         577243   895955    2019-10-29
# 4         577243   896036    2019-10-10
# ...          ...      ...           ...
# 318045  45431507  4375282    2019-08-27
# 318046  45443053  1660612    2019-12-24
# 318047  45471482  1945563    2019-08-10
# 318048  45471482  3309954    2019-11-15
# 318049  45471482  4563945    2019-11-15
#
# [318050 rows x 3 columns]

# %% [markdown]
# ### Add Days

# %%
from datetime import datetime
from datetime import timedelta

# %%
result_date = [start + timedelta(offset) for (start, offset) in zip(out_df['last_purchase'].to_list(), preds)]

# %% [markdown]
# ### Writing to File

# %%
final_df = pd.DataFrame()

# %%
final_df['next_purchase'] = result_date

# %%
final_df
# Out:
#        next_purchase
# 0         2019-10-28
# 1         2019-09-06
# 2         2020-03-02
# 3         2020-01-07
# 4         2019-12-16
# ...              ...
# 318045    2019-10-04
# 318046    2020-01-12
# 318047    2019-09-30
# 318048    2020-02-07
# 318049    2020-01-19
#
# [318050 rows x 1 columns]

# %%
final_df.to_csv('answer.csv', index=False)

# %% [markdown]
# ### References:
# - [Using Machine Learning to Predict Customers’ Next Purchase Day](https://towardsdatascience.com/using-machine-learning-to-predict-customers-next-purchase-day-7895ad49b4db)
# - [Predicting Next Purchase Day](https://towardsdatascience.com/predicting-next-purchase-day-15fae5548027)
